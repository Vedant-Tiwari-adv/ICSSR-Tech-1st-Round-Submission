# %%
# !pip install xgboost optuna pandas numpy
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.1.3)
# Collecting optuna
#   Downloading optuna-4.7.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.29.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost) (1.16.3)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.3)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.46)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.7.0-py3-none-any.whl (413 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.9/413.9 kB 6.6 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.7.0

# %%
# =====================================================
# MAX PERFORMANCE XGBOOST COMPETITION PIPELINE
# =====================================================

import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

import xgboost
print("XGBoost version:", xgboost.__version__)

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import roc_auc_score, average_precision_score, classification_report, f1_score
from xgboost import XGBClassifier
import optuna

# =====================================================
# 1. LOAD DATA
# =====================================================

file_path = r"/Customer_Churn.xlsx"
df = pd.read_excel(file_path)

df.drop(columns=["customerID"], errors="ignore", inplace=True)

df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")
df["TotalCharges"].fillna(0, inplace=True)
df["Churn"] = df["Churn"].map({"Yes":1, "No":0})

# =====================================================
# 2. STRONG FEATURE ENGINEERING
# =====================================================

df["avg_monthly"] = df["TotalCharges"] / (df["tenure"] + 1)
df["tenure_x_charge"] = df["tenure"] * df["MonthlyCharges"]
df["is_month_to_month"] = (df["Contract"] == "Month-to-month").astype(int)
df["fiber_flag"] = (df["InternetService"] == "Fiber optic").astype(int)

service_cols = [
    "PhoneService","MultipleLines","OnlineSecurity",
    "OnlineBackup","DeviceProtection",
    "TechSupport","StreamingTV","StreamingMovies"
]

existing_services = [c for c in service_cols if c in df.columns]
df["service_count"] = df[existing_services].apply(
    lambda row: sum(row == "Yes"), axis=1
)

# =====================================================
# 3. PREPARE DATA
# =====================================================

X = df.drop("Churn", axis=1)
y = df["Churn"]

X = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

scale_pos_weight = (y_train == 0).sum() / (y_train == 1).sum()

# =====================================================
# 4. OPTUNA TUNING (WIDE SEARCH SPACE)
# =====================================================

def objective(trial):

    params = {
        "n_estimators": trial.suggest_int("n_estimators", 800, 2000),
        "max_depth": trial.suggest_int("max_depth", 2, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.005, 0.15),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 10),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 15),
        "reg_alpha": trial.suggest_float("reg_alpha", 0, 20),
        "reg_lambda": trial.suggest_float("reg_lambda", 0.1, 20),
        "scale_pos_weight": scale_pos_weight,
        "tree_method": "hist",
        "predictor": "gpu_predictor",
        "eval_metric": "aucpr",
        "random_state": 42,
        "n_jobs": -1
    }

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = []

    for train_idx, val_idx in skf.split(X_train, y_train):
        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]

        model = XGBClassifier(**params)
        model.fit(X_tr, y_tr)

        preds = model.predict_proba(X_val)[:,1]
        score = average_precision_score(y_val, preds)
        scores.append(score)

    return np.mean(scores)

print("🔍 Running aggressive Optuna search...")
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=150)

best_params = study.best_params

best_params.update({
    "scale_pos_weight": scale_pos_weight,
    "tree_method": "hist",
    "predictor": "gpu_predictor",
    "eval_metric": "aucpr",
    "random_state": 42,
    "n_jobs": -1
})

print("Best Params Found:")
print(best_params)

# =====================================================
# 5. FINAL TRAINING WITH EARLY STOPPING
# =====================================================

final_xgb = XGBClassifier(
    **best_params,
    early_stopping_rounds=150
)

final_xgb.fit(
    X_train,
    y_train,
    eval_set=[(X_test, y_test)],
    verbose=False
)

xgb_prob = final_xgb.predict_proba(X_test)[:,1]

auc_score = roc_auc_score(y_test, xgb_prob)
aucpr_score = average_precision_score(y_test, xgb_prob)

print("\n🔥 FINAL XGBOOST AUC:", auc_score)
print("🔥 FINAL AUC-PR:", aucpr_score)

# =====================================================
# 6. FEATURE PRUNING (REMOVE WEAK FEATURES)
# =====================================================

importances = final_xgb.feature_importances_
threshold = np.percentile(importances, 10)

important_cols = X_train.columns[importances > threshold]

X_train_pruned = X_train[important_cols]
X_test_pruned = X_test[important_cols]

print("Features kept:", len(important_cols))

# Retrain on pruned features
final_xgb_pruned = XGBClassifier(
    **best_params,
    early_stopping_rounds=150
)

final_xgb_pruned.fit(
    X_train_pruned,
    y_train,
    eval_set=[(X_test_pruned, y_test)],
    verbose=False
)

final_prob = final_xgb_pruned.predict_proba(X_test_pruned)[:,1]

final_auc = roc_auc_score(y_test, final_prob)
print("\n🔥 PRUNED MODEL AUC:", final_auc)

# =====================================================
# 7. THRESHOLD OPTIMIZATION
# =====================================================

best_f1 = 0
best_threshold = 0.5

for t in np.arange(0.2, 0.8, 0.01):
    preds = (final_prob > t).astype(int)
    f1 = f1_score(y_test, preds)

    if f1 > best_f1:
        best_f1 = f1
        best_threshold = t

print("Best Threshold:", best_threshold)

y_pred_final = (final_prob > best_threshold).astype(int)

# =====================================================
# 8. FINAL REPORT
# =====================================================

print("\n===== FINAL CLASSIFICATION REPORT =====")
print(classification_report(y_test, y_pred_final))
print("FINAL AUC:", final_auc)
# Out:
# XGBoost version: 3.1.3
# [I 2026-02-11 18:29:04,529] A new study created in memory with name: no-name-8c3c5f43-6570-4e2f-80d4-07cb479335c0
# 🔍 Running aggressive Optuna search...
# [I 2026-02-11 18:29:10,870] Trial 0 finished with value: 0.6672965597661786 and parameters: {'n_estimators': 1622, 'max_depth': 6, 'learning_rate': 0.047613071669619075, 'subsample': 0.6661542342918452, 'colsample_bytree': 0.7972263478884166, 'gamma': 6.886248516418133, 'min_child_weight': 13, 'reg_alpha': 2.8052032952017014, 'reg_lambda': 6.885409772285795}. Best is trial 0 with value: 0.6672965597661786.
# [I 2026-02-11 18:29:14,530] Trial 1 finished with value: 0.6700298063885495 and parameters: {'n_estimators': 1451, 'max_depth': 2, 'learning_rate': 0.13894976190983852, 'subsample': 0.6761088639496132, 'colsample_bytree': 0.5092156866966919, 'gamma': 3.797336520982207, 'min_child_weight': 12, 'reg_alpha': 16.06376853445587, 'reg_lambda': 10.990307474420806}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:29:26,871] Trial 2 finished with value: 0.6385863344964345 and parameters: {'n_estimators': 1486, 'max_depth': 5, 'learning_rate': 0.08103926292485233, 'subsample': 0.6276081919220382, 'colsample_bytree': 0.9935790913553102, 'gamma': 0.014038046000881543, 'min_child_weight': 12, 'reg_alpha': 11.389825921458316, 'reg_lambda': 12.597643140791899}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:29:29,709] Trial 3 finished with value: 0.6694201440933026 and parameters: {'n_estimators': 862, 'max_depth': 7, 'learning_rate': 0.09373264184153762, 'subsample': 0.5399693638873595, 'colsample_bytree': 0.9719030487741904, 'gamma': 7.607992166235505, 'min_child_weight': 11, 'reg_alpha': 5.527758549018547, 'reg_lambda': 12.021453434634823}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:29:34,159] Trial 4 finished with value: 0.6646705720825465 and parameters: {'n_estimators': 909, 'max_depth': 9, 'learning_rate': 0.11651640848338386, 'subsample': 0.5610377524519448, 'colsample_bytree': 0.8617010317311209, 'gamma': 8.421714867573256, 'min_child_weight': 6, 'reg_alpha': 9.471567040661906, 'reg_lambda': 12.808833100715784}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:29:37,318] Trial 5 finished with value: 0.6517104783227327 and parameters: {'n_estimators': 1118, 'max_depth': 4, 'learning_rate': 0.12049422583562615, 'subsample': 0.9868449680365008, 'colsample_bytree': 0.7415381374721073, 'gamma': 9.628637104302626, 'min_child_weight': 12, 'reg_alpha': 19.943928924565693, 'reg_lambda': 3.4782914994028884}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:29:45,429] Trial 6 finished with value: 0.6318591322816732 and parameters: {'n_estimators': 1293, 'max_depth': 5, 'learning_rate': 0.09610079375521244, 'subsample': 0.5985051721225694, 'colsample_bytree': 0.6950715822197142, 'gamma': 1.966940583866953, 'min_child_weight': 8, 'reg_alpha': 1.9010655588020775, 'reg_lambda': 2.9022396846660623}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:29:49,344] Trial 7 finished with value: 0.6640972550272604 and parameters: {'n_estimators': 1444, 'max_depth': 9, 'learning_rate': 0.02826464931624078, 'subsample': 0.9197208779397121, 'colsample_bytree': 0.6348453198717712, 'gamma': 4.916070841873522, 'min_child_weight': 5, 'reg_alpha': 11.61561241087207, 'reg_lambda': 7.584160122342162}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:29:53,420] Trial 8 finished with value: 0.6670650527610389 and parameters: {'n_estimators': 1610, 'max_depth': 8, 'learning_rate': 0.13950434227164452, 'subsample': 0.7051937227239711, 'colsample_bytree': 0.5004188633680888, 'gamma': 4.118215324039688, 'min_child_weight': 1, 'reg_alpha': 16.162069636178117, 'reg_lambda': 1.4862018619573605}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:29:59,350] Trial 9 finished with value: 0.6687376903732851 and parameters: {'n_estimators': 1490, 'max_depth': 8, 'learning_rate': 0.12254081957928914, 'subsample': 0.5150862089434047, 'colsample_bytree': 0.6075131672869356, 'gamma': 5.8943952695926916, 'min_child_weight': 13, 'reg_alpha': 9.205479423396685, 'reg_lambda': 1.8108178994251658}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:30:04,222] Trial 10 finished with value: 0.6668757780687834 and parameters: {'n_estimators': 1900, 'max_depth': 2, 'learning_rate': 0.1481860612449911, 'subsample': 0.8056848389913903, 'colsample_bytree': 0.512794124953626, 'gamma': 3.0210537362399217, 'min_child_weight': 15, 'reg_alpha': 16.5054177395444, 'reg_lambda': 18.89929757027165}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:30:06,641] Trial 11 finished with value: 0.6676227839435748 and parameters: {'n_estimators': 822, 'max_depth': 2, 'learning_rate': 0.05611458695444329, 'subsample': 0.7932117042907781, 'colsample_bytree': 0.9872906597367808, 'gamma': 7.296196513365855, 'min_child_weight': 10, 'reg_alpha': 5.0723158904224634, 'reg_lambda': 15.600514481440083}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:30:12,275] Trial 12 finished with value: 0.6648140996985404 and parameters: {'n_estimators': 1219, 'max_depth': 7, 'learning_rate': 0.09458738816945642, 'subsample': 0.7344129756521858, 'colsample_bytree': 0.8933894617329878, 'gamma': 3.4753827049284096, 'min_child_weight': 9, 'reg_alpha': 7.039920171064117, 'reg_lambda': 9.962446978366078}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:30:15,674] Trial 13 finished with value: 0.6660244005234985 and parameters: {'n_estimators': 1051, 'max_depth': 3, 'learning_rate': 0.06801150415390046, 'subsample': 0.5103265268692876, 'colsample_bytree': 0.8751075362476958, 'gamma': 6.290385267114415, 'min_child_weight': 10, 'reg_alpha': 14.753981423427776, 'reg_lambda': 14.990194765614874}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:30:25,248] Trial 14 finished with value: 0.6670179319922193 and parameters: {'n_estimators': 1847, 'max_depth': 10, 'learning_rate': 0.005276813672696862, 'subsample': 0.628442946090417, 'colsample_bytree': 0.5726573585784691, 'gamma': 8.166376820333472, 'min_child_weight': 7, 'reg_alpha': 0.21983977517090558, 'reg_lambda': 9.553580213533253}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:30:30,284] Trial 15 finished with value: 0.6609394367420914 and parameters: {'n_estimators': 1685, 'max_depth': 7, 'learning_rate': 0.10728570766623043, 'subsample': 0.8491535946878049, 'colsample_bytree': 0.6923085235319992, 'gamma': 2.070020619778171, 'min_child_weight': 15, 'reg_alpha': 5.296015081836672, 'reg_lambda': 12.651037407505296}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:30:33,732] Trial 16 finished with value: 0.661500078661861 and parameters: {'n_estimators': 1310, 'max_depth': 4, 'learning_rate': 0.132920160885554, 'subsample': 0.700814800384851, 'colsample_bytree': 0.8107283353738124, 'gamma': 9.82569599643935, 'min_child_weight': 4, 'reg_alpha': 18.916836206359815, 'reg_lambda': 6.734050250434208}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:30:39,404] Trial 17 finished with value: 0.6676237180030361 and parameters: {'n_estimators': 1007, 'max_depth': 6, 'learning_rate': 0.08641507907261875, 'subsample': 0.5618239952181168, 'colsample_bytree': 0.9153424793392011, 'gamma': 5.370525484907994, 'min_child_weight': 11, 'reg_alpha': 13.560614694956756, 'reg_lambda': 17.28624542144546}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:30:53,249] Trial 18 finished with value: 0.6255438544013726 and parameters: {'n_estimators': 1755, 'max_depth': 4, 'learning_rate': 0.10495240732558221, 'subsample': 0.6626430077459784, 'colsample_bytree': 0.9345070346333385, 'gamma': 0.20374730129820762, 'min_child_weight': 14, 'reg_alpha': 7.198772899794511, 'reg_lambda': 10.895956291217777}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:30:56,919] Trial 19 finished with value: 0.6653162120617446 and parameters: {'n_estimators': 1150, 'max_depth': 7, 'learning_rate': 0.06766015196115689, 'subsample': 0.5627808374799506, 'colsample_bytree': 0.7939119452673024, 'gamma': 4.801758756887553, 'min_child_weight': 9, 'reg_alpha': 17.66494134025593, 'reg_lambda': 15.570698895858255}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:31:02,749] Trial 20 finished with value: 0.6622759207533268 and parameters: {'n_estimators': 1354, 'max_depth': 3, 'learning_rate': 0.14767248914075376, 'subsample': 0.772096873484464, 'colsample_bytree': 0.5705824747576853, 'gamma': 8.38061850521468, 'min_child_weight': 11, 'reg_alpha': 12.843687491353965, 'reg_lambda': 5.014401252403941}. Best is trial 1 with value: 0.6700298063885495.
# [I 2026-02-11 18:31:07,849] Trial 21 finished with value: 0.67140470238963 and parameters: {'n_estimators': 1541, 'max_depth': 8, 'learning_rate': 0.1270368164407098, 'subsample': 0.5020937703954308, 'colsample_bytree': 0.5691074938074083, 'gamma': 6.015671295844143, 'min_child_weight': 13, 'reg_alpha': 9.205590206220847, 'reg_lambda': 0.21678751543783292}. Best is trial 21 with value: 0.67140470238963.
# [I 2026-02-11 18:31:12,378] Trial 22 finished with value: 0.6710327761228554 and parameters: {'n_estimators': 1554, 'max_depth': 8, 'learning_rate': 0.12759741483063577, 'subsample': 0.5080729300340638, 'colsample_bytree': 0.5390447805807073, 'gamma': 7.274995522327197, 'min_child_weight': 13, 'reg_alpha': 7.513312934709846, 'reg_lambda': 8.19701607661988}. Best is trial 21 with value: 0.67140470238963.
# [I 2026-02-11 18:31:19,507] Trial 23 finished with value: 0.6683109236372516 and parameters: {'n_estimators': 1561, 'max_depth': 10, 'learning_rate': 0.13284213420889693, 'subsample': 0.5030337443051898, 'colsample_bytree': 0.5411071421508462, 'gamma': 6.09298735869921, 'min_child_weight': 13, 'reg_alpha': 8.018341478849694, 'reg_lambda': 8.36549769977015}. Best is trial 21 with value: 0.67140470238963.
# [I 2026-02-11 18:31:24,726] Trial 24 finished with value: 0.6721380395681495 and parameters: {'n_estimators': 1788, 'max_depth': 9, 'learning_rate': 0.12413495586925252, 'subsample': 0.5965306041991241, 'colsample_bytree': 0.6300681036179655, 'gamma': 3.7805016511251135, 'min_child_weight': 14, 'reg_alpha': 10.869924819619547, 'reg_lambda': 4.7449117733302595}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:31:32,999] Trial 25 finished with value: 0.666935360370924 and parameters: {'n_estimators': 1980, 'max_depth': 9, 'learning_rate': 0.11069191717751715, 'subsample': 0.5986691558682119, 'colsample_bytree': 0.6410882371350772, 'gamma': 2.519530633580753, 'min_child_weight': 15, 'reg_alpha': 10.475162463348518, 'reg_lambda': 4.962603163275775}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:31:37,678] Trial 26 finished with value: 0.6713195028000545 and parameters: {'n_estimators': 1751, 'max_depth': 8, 'learning_rate': 0.12607321466888363, 'subsample': 0.6004091066533832, 'colsample_bytree': 0.5872706386279961, 'gamma': 4.51471797608621, 'min_child_weight': 14, 'reg_alpha': 8.385935429352806, 'reg_lambda': 0.3844843697237662}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:31:46,371] Trial 27 finished with value: 0.6523645864765604 and parameters: {'n_estimators': 1782, 'max_depth': 9, 'learning_rate': 0.11473606433483052, 'subsample': 0.6142117237266526, 'colsample_bytree': 0.6820231105558604, 'gamma': 1.1411428201610625, 'min_child_weight': 14, 'reg_alpha': 12.179121987732572, 'reg_lambda': 0.721459823916947}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:31:51,133] Trial 28 finished with value: 0.6677517981602213 and parameters: {'n_estimators': 1700, 'max_depth': 10, 'learning_rate': 0.10272678722125043, 'subsample': 0.5801103857271122, 'colsample_bytree': 0.6062473250743932, 'gamma': 4.596933764137595, 'min_child_weight': 14, 'reg_alpha': 10.441980345858948, 'reg_lambda': 0.40238972456438804}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:31:58,805] Trial 29 finished with value: 0.6665350016702927 and parameters: {'n_estimators': 1982, 'max_depth': 8, 'learning_rate': 0.03800077554444786, 'subsample': 0.6545258875139549, 'colsample_bytree': 0.6548441960209618, 'gamma': 5.3777910406005525, 'min_child_weight': 14, 'reg_alpha': 2.8464103449630587, 'reg_lambda': 4.327559853356613}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:32:03,621] Trial 30 finished with value: 0.6699529657293921 and parameters: {'n_estimators': 1868, 'max_depth': 6, 'learning_rate': 0.13033213747496014, 'subsample': 0.6422080593584183, 'colsample_bytree': 0.5799616874147606, 'gamma': 4.434073955645204, 'min_child_weight': 3, 'reg_alpha': 8.69143466480708, 'reg_lambda': 2.364338926108095}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:32:09,873] Trial 31 finished with value: 0.6688154451453705 and parameters: {'n_estimators': 1578, 'max_depth': 8, 'learning_rate': 0.12364056818600691, 'subsample': 0.5316488045553244, 'colsample_bytree': 0.6020257580948961, 'gamma': 6.681556198283184, 'min_child_weight': 13, 'reg_alpha': 6.402612641306464, 'reg_lambda': 0.3870251213952488}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:32:15,114] Trial 32 finished with value: 0.6532298790896882 and parameters: {'n_estimators': 1683, 'max_depth': 8, 'learning_rate': 0.1399862045553662, 'subsample': 0.5433801760456214, 'colsample_bytree': 0.5431813814870613, 'gamma': 3.5704649588716473, 'min_child_weight': 12, 'reg_alpha': 3.537566770637524, 'reg_lambda': 6.429669674395459}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:32:21,314] Trial 33 finished with value: 0.670568087059453 and parameters: {'n_estimators': 1532, 'max_depth': 9, 'learning_rate': 0.12603137366217046, 'subsample': 0.500431184959943, 'colsample_bytree': 0.5607787660522955, 'gamma': 5.580258615940573, 'min_child_weight': 15, 'reg_alpha': 7.9145423542734505, 'reg_lambda': 3.8604370881152725}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:32:26,010] Trial 34 finished with value: 0.6690028940888555 and parameters: {'n_estimators': 1757, 'max_depth': 7, 'learning_rate': 0.1423021704172921, 'subsample': 0.5784667617526683, 'colsample_bytree': 0.540112904040157, 'gamma': 6.875213203767359, 'min_child_weight': 12, 'reg_alpha': 10.93278160885462, 'reg_lambda': 5.756030276078166}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:32:30,537] Trial 35 finished with value: 0.6674722673155113 and parameters: {'n_estimators': 1635, 'max_depth': 9, 'learning_rate': 0.11509882709286405, 'subsample': 0.5485749040822744, 'colsample_bytree': 0.6175743324058798, 'gamma': 7.570487316098479, 'min_child_weight': 13, 'reg_alpha': 13.973711587802791, 'reg_lambda': 8.682956629418824}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:32:37,912] Trial 36 finished with value: 0.67025857036764 and parameters: {'n_estimators': 1822, 'max_depth': 8, 'learning_rate': 0.13371935871724816, 'subsample': 0.6033851672851703, 'colsample_bytree': 0.7367266768128886, 'gamma': 4.078216251059205, 'min_child_weight': 13, 'reg_alpha': 9.585834210528617, 'reg_lambda': 2.6743543324669363}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:32:41,783] Trial 37 finished with value: 0.6686222768185832 and parameters: {'n_estimators': 1396, 'max_depth': 6, 'learning_rate': 0.09957909028648804, 'subsample': 0.6777466166417556, 'colsample_bytree': 0.6624749193950534, 'gamma': 6.529992222819868, 'min_child_weight': 11, 'reg_alpha': 4.055835531576557, 'reg_lambda': 1.4236176701422554}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:32:48,919] Trial 38 finished with value: 0.6595256864988274 and parameters: {'n_estimators': 1492, 'max_depth': 10, 'learning_rate': 0.08162859597676413, 'subsample': 0.5288638989649248, 'colsample_bytree': 0.7205259947930451, 'gamma': 2.793628770605726, 'min_child_weight': 14, 'reg_alpha': 6.2856921669109385, 'reg_lambda': 3.417418910990623}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:32:53,678] Trial 39 finished with value: 0.6660544583233368 and parameters: {'n_estimators': 1920, 'max_depth': 7, 'learning_rate': 0.11612875670009161, 'subsample': 0.6226344516558999, 'colsample_bytree': 0.5257362219639311, 'gamma': 7.189735765312409, 'min_child_weight': 12, 'reg_alpha': 11.831080716970384, 'reg_lambda': 8.206312203154184}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:33:00,095] Trial 40 finished with value: 0.6683147040067595 and parameters: {'n_estimators': 1619, 'max_depth': 9, 'learning_rate': 0.12580488663096487, 'subsample': 0.5889466385961696, 'colsample_bytree': 0.5889358600152484, 'gamma': 7.960546813272045, 'min_child_weight': 15, 'reg_alpha': 8.487115883926492, 'reg_lambda': 4.797533530213305}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:33:04,763] Trial 41 finished with value: 0.668734849372909 and parameters: {'n_estimators': 1532, 'max_depth': 9, 'learning_rate': 0.12505229120880598, 'subsample': 0.5153634017620663, 'colsample_bytree': 0.5626518768393252, 'gamma': 5.41254124059116, 'min_child_weight': 15, 'reg_alpha': 7.538889092567623, 'reg_lambda': 3.80230506656611}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:33:08,918] Trial 42 finished with value: 0.6700209125022283 and parameters: {'n_estimators': 1413, 'max_depth': 8, 'learning_rate': 0.1289535531561886, 'subsample': 0.5376196776696103, 'colsample_bytree': 0.558874660204153, 'gamma': 5.839316669155207, 'min_child_weight': 14, 'reg_alpha': 9.49559452853723, 'reg_lambda': 1.9019158338324438}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:33:15,095] Trial 43 finished with value: 0.6711012444351365 and parameters: {'n_estimators': 1530, 'max_depth': 9, 'learning_rate': 0.11874553174340063, 'subsample': 0.5674528153277315, 'colsample_bytree': 0.6221259854237874, 'gamma': 5.147193819819317, 'min_child_weight': 13, 'reg_alpha': 8.343496034044652, 'reg_lambda': 6.037942756593134}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:33:19,549] Trial 44 finished with value: 0.669896728296892 and parameters: {'n_estimators': 1659, 'max_depth': 8, 'learning_rate': 0.13876980304123188, 'subsample': 0.5719902377919254, 'colsample_bytree': 0.6245412582527182, 'gamma': 8.82520584826177, 'min_child_weight': 10, 'reg_alpha': 6.265932737199205, 'reg_lambda': 5.960721530561461}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:33:25,991] Trial 45 finished with value: 0.6643198603522031 and parameters: {'n_estimators': 1483, 'max_depth': 10, 'learning_rate': 0.11922470962054464, 'subsample': 0.6879089190974162, 'colsample_bytree': 0.5183786619267917, 'gamma': 9.0109893842493, 'min_child_weight': 11, 'reg_alpha': 10.008751553578673, 'reg_lambda': 7.673972205536735}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:33:31,660] Trial 46 finished with value: 0.6679522821247752 and parameters: {'n_estimators': 1728, 'max_depth': 9, 'learning_rate': 0.10988760942342586, 'subsample': 0.5537572432914484, 'colsample_bytree': 0.6728457627461774, 'gamma': 3.856562862592523, 'min_child_weight': 13, 'reg_alpha': 8.893747312939404, 'reg_lambda': 7.184408850515859}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:33:39,705] Trial 47 finished with value: 0.6629811716283449 and parameters: {'n_estimators': 1811, 'max_depth': 7, 'learning_rate': 0.0880569872945082, 'subsample': 0.9733991569189493, 'colsample_bytree': 0.6388642278318516, 'gamma': 3.2638615020757387, 'min_child_weight': 12, 'reg_alpha': 10.83845206249502, 'reg_lambda': 1.1751492578829774}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:33:44,703] Trial 48 finished with value: 0.6651577476539459 and parameters: {'n_estimators': 1596, 'max_depth': 5, 'learning_rate': 0.1354276180856253, 'subsample': 0.7347957118278687, 'colsample_bytree': 0.7722949213039718, 'gamma': 5.074667634494092, 'min_child_weight': 7, 'reg_alpha': 4.527021489056789, 'reg_lambda': 9.43161298079083}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:33:48,733] Trial 49 finished with value: 0.6673046181336295 and parameters: {'n_estimators': 1361, 'max_depth': 8, 'learning_rate': 0.14571901131825193, 'subsample': 0.6394411467049103, 'colsample_bytree': 0.7044202140087736, 'gamma': 4.489751757882224, 'min_child_weight': 12, 'reg_alpha': 12.61353567795804, 'reg_lambda': 11.027268939766635}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:33:54,990] Trial 50 finished with value: 0.6623797598839106 and parameters: {'n_estimators': 1451, 'max_depth': 10, 'learning_rate': 0.11977165084232308, 'subsample': 0.8707957083974505, 'colsample_bytree': 0.5031210872345634, 'gamma': 6.255276444115392, 'min_child_weight': 1, 'reg_alpha': 6.663371943325433, 'reg_lambda': 2.947924486345946}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:33:59,548] Trial 51 finished with value: 0.6701501490968366 and parameters: {'n_estimators': 1542, 'max_depth': 9, 'learning_rate': 0.12823409841430838, 'subsample': 0.5055312850267584, 'colsample_bytree': 0.5924498136969016, 'gamma': 5.658824194715787, 'min_child_weight': 15, 'reg_alpha': 7.892429941081257, 'reg_lambda': 3.791461220421965}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:34:05,977] Trial 52 finished with value: 0.6675102526435316 and parameters: {'n_estimators': 1517, 'max_depth': 9, 'learning_rate': 0.1117005580438114, 'subsample': 0.5311387138868995, 'colsample_bytree': 0.5477489225693177, 'gamma': 5.183527132003478, 'min_child_weight': 13, 'reg_alpha': 8.096424005211329, 'reg_lambda': 5.7297725111419835}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:34:09,790] Trial 53 finished with value: 0.6699447859548016 and parameters: {'n_estimators': 1283, 'max_depth': 8, 'learning_rate': 0.11970213121936517, 'subsample': 0.5212523051918344, 'colsample_bytree': 0.5278028060368831, 'gamma': 7.165168326713963, 'min_child_weight': 14, 'reg_alpha': 5.8229836302460125, 'reg_lambda': 4.41049718671774}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:34:13,963] Trial 54 finished with value: 0.6663029051144072 and parameters: {'n_estimators': 1443, 'max_depth': 9, 'learning_rate': 0.14288775837749945, 'subsample': 0.5008638552625108, 'colsample_bytree': 0.5754496509060578, 'gamma': 4.101287598334881, 'min_child_weight': 15, 'reg_alpha': 9.226307356627515, 'reg_lambda': 2.427810182056413}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:34:20,448] Trial 55 finished with value: 0.668351929552743 and parameters: {'n_estimators': 1619, 'max_depth': 8, 'learning_rate': 0.10172821820082384, 'subsample': 0.5484769625340173, 'colsample_bytree': 0.6254389677749003, 'gamma': 4.810431120921759, 'min_child_weight': 13, 'reg_alpha': 7.5404276347126515, 'reg_lambda': 6.646398301343409}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:34:25,206] Trial 56 finished with value: 0.6699834643337489 and parameters: {'n_estimators': 1731, 'max_depth': 9, 'learning_rate': 0.13610561481821237, 'subsample': 0.5700648259856503, 'colsample_bytree': 0.839659763270207, 'gamma': 5.746765249508236, 'min_child_weight': 14, 'reg_alpha': 11.151635031032226, 'reg_lambda': 1.1001706777127045}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:34:32,647] Trial 57 finished with value: 0.6704572985566937 and parameters: {'n_estimators': 1925, 'max_depth': 10, 'learning_rate': 0.1252458902805102, 'subsample': 0.6075638843659814, 'colsample_bytree': 0.5999288696675573, 'gamma': 6.5082906973412324, 'min_child_weight': 15, 'reg_alpha': 7.072724516737088, 'reg_lambda': 3.2274313739580665}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:34:37,274] Trial 58 finished with value: 0.6693350362457056 and parameters: {'n_estimators': 1567, 'max_depth': 7, 'learning_rate': 0.09291303643433174, 'subsample': 0.5004937387582146, 'colsample_bytree': 0.5613626676010267, 'gamma': 4.368393879089182, 'min_child_weight': 10, 'reg_alpha': 10.037292304153535, 'reg_lambda': 5.42522968955255}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:34:45,199] Trial 59 finished with value: 0.6680730737773644 and parameters: {'n_estimators': 1658, 'max_depth': 9, 'learning_rate': 0.012565964201392374, 'subsample': 0.5838152479354808, 'colsample_bytree': 0.6422231702307744, 'gamma': 6.078480293774882, 'min_child_weight': 14, 'reg_alpha': 8.357217289396196, 'reg_lambda': 2.11386129951046}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:34:49,203] Trial 60 finished with value: 0.6619197103543081 and parameters: {'n_estimators': 1263, 'max_depth': 8, 'learning_rate': 0.10696248870514685, 'subsample': 0.5210969616301743, 'colsample_bytree': 0.5882092774478891, 'gamma': 3.7462409669031858, 'min_child_weight': 13, 'reg_alpha': 5.804796718235993, 'reg_lambda': 0.2355838292056834}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:34:54,338] Trial 61 finished with value: 0.6707973810813342 and parameters: {'n_estimators': 1939, 'max_depth': 10, 'learning_rate': 0.14933471877350354, 'subsample': 0.6061199948923892, 'colsample_bytree': 0.6128942150611938, 'gamma': 6.528908983041045, 'min_child_weight': 15, 'reg_alpha': 7.040314939362273, 'reg_lambda': 3.39955301374417}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:35:01,208] Trial 62 finished with value: 0.6672333731541376 and parameters: {'n_estimators': 1876, 'max_depth': 10, 'learning_rate': 0.1493236228924003, 'subsample': 0.5613880140946584, 'colsample_bytree': 0.6074856494915202, 'gamma': 7.486433380530721, 'min_child_weight': 15, 'reg_alpha': 5.033206580821988, 'reg_lambda': 4.059249479383444}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:35:06,256] Trial 63 finished with value: 0.6685729894287193 and parameters: {'n_estimators': 1995, 'max_depth': 10, 'learning_rate': 0.132352936572843, 'subsample': 0.5940896420046587, 'colsample_bytree': 0.6582629118575479, 'gamma': 7.920022594670483, 'min_child_weight': 14, 'reg_alpha': 9.177956208399884, 'reg_lambda': 7.513062760492074}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:35:13,829] Trial 64 finished with value: 0.6691124052215809 and parameters: {'n_estimators': 1804, 'max_depth': 9, 'learning_rate': 0.13825561030090555, 'subsample': 0.651181766197131, 'colsample_bytree': 0.6185808774584267, 'gamma': 5.563471474004366, 'min_child_weight': 15, 'reg_alpha': 6.944337240682926, 'reg_lambda': 5.00684894850945}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:35:18,307] Trial 65 finished with value: 0.6701134482627866 and parameters: {'n_estimators': 1705, 'max_depth': 9, 'learning_rate': 0.1445849943525204, 'subsample': 0.6139801145579917, 'colsample_bytree': 0.5504058770527688, 'gamma': 4.875244597233659, 'min_child_weight': 13, 'reg_alpha': 9.967304847881195, 'reg_lambda': 6.443798668959914}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:35:24,231] Trial 66 finished with value: 0.669273068141164 and parameters: {'n_estimators': 1486, 'max_depth': 10, 'learning_rate': 0.05935862545037954, 'subsample': 0.6313979022183194, 'colsample_bytree': 0.5761126558171661, 'gamma': 5.9814656929837176, 'min_child_weight': 14, 'reg_alpha': 7.67834150775142, 'reg_lambda': 1.590087499404392}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:35:29,252] Trial 67 finished with value: 0.6704301694722108 and parameters: {'n_estimators': 1940, 'max_depth': 8, 'learning_rate': 0.1288975752701922, 'subsample': 0.5413306666451946, 'colsample_bytree': 0.5323101131436041, 'gamma': 6.920044135110708, 'min_child_weight': 14, 'reg_alpha': 8.442896920199436, 'reg_lambda': 13.965583262616484}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:35:35,713] Trial 68 finished with value: 0.6702916179351226 and parameters: {'n_estimators': 1657, 'max_depth': 8, 'learning_rate': 0.11301709300432487, 'subsample': 0.565629388601078, 'colsample_bytree': 0.5169988578734113, 'gamma': 5.145552706077552, 'min_child_weight': 13, 'reg_alpha': 11.566248089006372, 'reg_lambda': 3.07418349432035}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:35:40,827] Trial 69 finished with value: 0.6486733078156399 and parameters: {'n_estimators': 1858, 'max_depth': 10, 'learning_rate': 0.1233627083493783, 'subsample': 0.5180080684337128, 'colsample_bytree': 0.6484318776372044, 'gamma': 6.4315985914060985, 'min_child_weight': 5, 'reg_alpha': 1.1144017652019418, 'reg_lambda': 0.9622757816800371}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:35:45,716] Trial 70 finished with value: 0.6684000314084224 and parameters: {'n_estimators': 1785, 'max_depth': 9, 'learning_rate': 0.11703025253224607, 'subsample': 0.706384660090413, 'colsample_bytree': 0.6805734994933734, 'gamma': 2.267018375567293, 'min_child_weight': 12, 'reg_alpha': 15.056955632109918, 'reg_lambda': 9.113211558779598}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:35:52,296] Trial 71 finished with value: 0.6702733885802533 and parameters: {'n_estimators': 1926, 'max_depth': 10, 'learning_rate': 0.1247851233341239, 'subsample': 0.6108644359661499, 'colsample_bytree': 0.5922685588397592, 'gamma': 6.765345379351281, 'min_child_weight': 15, 'reg_alpha': 7.089344395004796, 'reg_lambda': 3.2914468587592847}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:35:57,363] Trial 72 finished with value: 0.669932457143366 and parameters: {'n_estimators': 1890, 'max_depth': 10, 'learning_rate': 0.13150745712188883, 'subsample': 0.5925413965902204, 'colsample_bytree': 0.6023438640657858, 'gamma': 6.160064026021797, 'min_child_weight': 15, 'reg_alpha': 8.842864543483762, 'reg_lambda': 2.3045058300796475}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:36:04,502] Trial 73 finished with value: 0.669656745740304 and parameters: {'n_estimators': 1942, 'max_depth': 10, 'learning_rate': 0.14087997923131715, 'subsample': 0.5516172506322535, 'colsample_bytree': 0.6292786739132962, 'gamma': 6.587652846922498, 'min_child_weight': 14, 'reg_alpha': 7.365351449063355, 'reg_lambda': 4.3976070812689585}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:36:09,647] Trial 74 finished with value: 0.6677000872304264 and parameters: {'n_estimators': 1850, 'max_depth': 9, 'learning_rate': 0.12122230890712321, 'subsample': 0.6647404960036221, 'colsample_bytree': 0.5661207183066802, 'gamma': 7.122879520805284, 'min_child_weight': 15, 'reg_alpha': 5.478447675630862, 'reg_lambda': 3.571579799764952}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:36:16,659] Trial 75 finished with value: 0.664111916056288 and parameters: {'n_estimators': 1758, 'max_depth': 7, 'learning_rate': 0.1273587064611896, 'subsample': 0.6200583923599697, 'colsample_bytree': 0.5851648804791895, 'gamma': 3.220223715793836, 'min_child_weight': 12, 'reg_alpha': 6.535243731936995, 'reg_lambda': 2.7232632567906823}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:36:23,653] Trial 76 finished with value: 0.656349375033079 and parameters: {'n_estimators': 1950, 'max_depth': 10, 'learning_rate': 0.1069930883790497, 'subsample': 0.577999027893517, 'colsample_bytree': 0.6059960500999729, 'gamma': 1.550877055780913, 'min_child_weight': 15, 'reg_alpha': 9.694420966990187, 'reg_lambda': 6.067799971214461}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:36:30,134] Trial 77 finished with value: 0.6691917803898993 and parameters: {'n_estimators': 1832, 'max_depth': 9, 'learning_rate': 0.1164872400003821, 'subsample': 0.6033611367852406, 'colsample_bytree': 0.5488127477808258, 'gamma': 5.3379599197978775, 'min_child_weight': 14, 'reg_alpha': 10.276273446853523, 'reg_lambda': 0.19619484590865027}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:36:34,427] Trial 78 finished with value: 0.6663444635949529 and parameters: {'n_estimators': 1592, 'max_depth': 8, 'learning_rate': 0.13563368846498994, 'subsample': 0.5334924645185459, 'colsample_bytree': 0.6179123580596111, 'gamma': 4.733725015452956, 'min_child_weight': 15, 'reg_alpha': 4.769290937225742, 'reg_lambda': 5.4813692228846636}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:36:39,893] Trial 79 finished with value: 0.6684087696116435 and parameters: {'n_estimators': 1378, 'max_depth': 9, 'learning_rate': 0.07488907859817061, 'subsample': 0.6469729888951313, 'colsample_bytree': 0.6650888176449392, 'gamma': 7.82145152367111, 'min_child_weight': 13, 'reg_alpha': 8.139992974987678, 'reg_lambda': 1.7191619521108075}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:36:43,770] Trial 80 finished with value: 0.6670984697624011 and parameters: {'n_estimators': 1524, 'max_depth': 5, 'learning_rate': 0.12272591281825278, 'subsample': 0.6339186410447308, 'colsample_bytree': 0.5604164872636979, 'gamma': 6.409063068576021, 'min_child_weight': 14, 'reg_alpha': 8.963741435848059, 'reg_lambda': 18.943595681839724}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:36:48,542] Trial 81 finished with value: 0.6676310239868777 and parameters: {'n_estimators': 1957, 'max_depth': 8, 'learning_rate': 0.12960638427965573, 'subsample': 0.5418929004729324, 'colsample_bytree': 0.5067023499146817, 'gamma': 6.96727540845784, 'min_child_weight': 14, 'reg_alpha': 8.503933376947753, 'reg_lambda': 14.78599646634858}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:36:55,240] Trial 82 finished with value: 0.6682931990116485 and parameters: {'n_estimators': 1895, 'max_depth': 7, 'learning_rate': 0.1275284738173401, 'subsample': 0.5211872769924104, 'colsample_bytree': 0.5340317051847618, 'gamma': 7.430689142298809, 'min_child_weight': 13, 'reg_alpha': 10.655208979192123, 'reg_lambda': 16.81359535855924}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:36:58,950] Trial 83 finished with value: 0.671145105713818 and parameters: {'n_estimators': 1431, 'max_depth': 8, 'learning_rate': 0.136876441149731, 'subsample': 0.5571602069677192, 'colsample_bytree': 0.5316606328031032, 'gamma': 6.8618686975844065, 'min_child_weight': 14, 'reg_alpha': 6.952112076616602, 'reg_lambda': 4.61395241064666}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:37:02,801] Trial 84 finished with value: 0.6680757868278626 and parameters: {'n_estimators': 1421, 'max_depth': 8, 'learning_rate': 0.14982482667460106, 'subsample': 0.5561674403724185, 'colsample_bytree': 0.5724023121630107, 'gamma': 5.9275981101536255, 'min_child_weight': 15, 'reg_alpha': 5.839717834318255, 'reg_lambda': 4.7134934132242226}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:37:08,324] Trial 85 finished with value: 0.6682095843928353 and parameters: {'n_estimators': 1457, 'max_depth': 9, 'learning_rate': 0.14599018117671791, 'subsample': 0.5137887029188708, 'colsample_bytree': 0.5959275234076009, 'gamma': 5.57514967212043, 'min_child_weight': 12, 'reg_alpha': 7.066405578320271, 'reg_lambda': 4.097482235658008}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:37:12,150] Trial 86 finished with value: 0.6679291229521469 and parameters: {'n_estimators': 1546, 'max_depth': 10, 'learning_rate': 0.13812262460888944, 'subsample': 0.587411857995068, 'colsample_bytree': 0.5183940850880178, 'gamma': 6.70015252275556, 'min_child_weight': 14, 'reg_alpha': 6.1676005786361126, 'reg_lambda': 5.347035718534827}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:37:17,097] Trial 87 finished with value: 0.6641268129910236 and parameters: {'n_estimators': 1313, 'max_depth': 8, 'learning_rate': 0.13308158192537362, 'subsample': 0.7970196176659319, 'colsample_bytree': 0.9598034816536921, 'gamma': 4.2310833353120225, 'min_child_weight': 8, 'reg_alpha': 7.824539275851489, 'reg_lambda': 10.434654863004248}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:37:21,216] Trial 88 finished with value: 0.6701197623265321 and parameters: {'n_estimators': 1508, 'max_depth': 7, 'learning_rate': 0.13981693712783644, 'subsample': 0.6067186307416054, 'colsample_bytree': 0.5474541888453411, 'gamma': 6.298226504320281, 'min_child_weight': 11, 'reg_alpha': 6.765625854500931, 'reg_lambda': 7.001256954210466}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:37:24,635] Trial 89 finished with value: 0.6676759361217522 and parameters: {'n_estimators': 1331, 'max_depth': 3, 'learning_rate': 0.11869579535635007, 'subsample': 0.5714482622292808, 'colsample_bytree': 0.6133084868194818, 'gamma': 8.534693535579404, 'min_child_weight': 13, 'reg_alpha': 9.363398541777258, 'reg_lambda': 8.048333595829305}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:37:31,479] Trial 90 finished with value: 0.6503459920813098 and parameters: {'n_estimators': 1636, 'max_depth': 6, 'learning_rate': 0.14424343273828394, 'subsample': 0.5321256395195677, 'colsample_bytree': 0.5804535090630426, 'gamma': 3.8025848868649934, 'min_child_weight': 15, 'reg_alpha': 4.348244912442791, 'reg_lambda': 0.6395631773001369}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:37:36,419] Trial 91 finished with value: 0.6702569595651064 and parameters: {'n_estimators': 1974, 'max_depth': 8, 'learning_rate': 0.13011763913624336, 'subsample': 0.5416258095038367, 'colsample_bytree': 0.5317049333720747, 'gamma': 7.011654152392506, 'min_child_weight': 14, 'reg_alpha': 8.418579881045137, 'reg_lambda': 13.262142140460385}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:37:42,850] Trial 92 finished with value: 0.67045304143486 and parameters: {'n_estimators': 1902, 'max_depth': 8, 'learning_rate': 0.12644489370859108, 'subsample': 0.5098413551919714, 'colsample_bytree': 0.555528223464645, 'gamma': 7.705941453585175, 'min_child_weight': 14, 'reg_alpha': 7.521411444087802, 'reg_lambda': 11.345680226903621}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:37:47,292] Trial 93 finished with value: 0.6695959839884985 and parameters: {'n_estimators': 1567, 'max_depth': 9, 'learning_rate': 0.13547758705809376, 'subsample': 0.5084015392977222, 'colsample_bytree': 0.5521872721305753, 'gamma': 7.773070094193178, 'min_child_weight': 14, 'reg_alpha': 7.371080608653831, 'reg_lambda': 11.751109104877308}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:37:51,933] Trial 94 finished with value: 0.6684999456045677 and parameters: {'n_estimators': 1915, 'max_depth': 8, 'learning_rate': 0.12500826260786035, 'subsample': 0.5252017691334718, 'colsample_bytree': 0.6340118027537431, 'gamma': 8.184438778216384, 'min_child_weight': 15, 'reg_alpha': 7.808613444710431, 'reg_lambda': 6.154145748196502}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:37:57,514] Trial 95 finished with value: 0.671043425096232 and parameters: {'n_estimators': 1468, 'max_depth': 7, 'learning_rate': 0.11081407396456738, 'subsample': 0.5127460814261208, 'colsample_bytree': 0.5712877488358199, 'gamma': 7.531870326212686, 'min_child_weight': 13, 'reg_alpha': 6.09325494392243, 'reg_lambda': 11.780480769275263}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:38:01,222] Trial 96 finished with value: 0.6695755483112447 and parameters: {'n_estimators': 1465, 'max_depth': 7, 'learning_rate': 0.11426396122710847, 'subsample': 0.5572551420935924, 'colsample_bytree': 0.5681051552252337, 'gamma': 7.376080556811836, 'min_child_weight': 13, 'reg_alpha': 6.089745345220345, 'reg_lambda': 10.356616852967534}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:38:04,919] Trial 97 finished with value: 0.6694499144973342 and parameters: {'n_estimators': 1409, 'max_depth': 6, 'learning_rate': 0.10855199119511573, 'subsample': 0.5789454264951858, 'colsample_bytree': 0.5957519048936623, 'gamma': 5.810594674167974, 'min_child_weight': 12, 'reg_alpha': 3.399554045030081, 'reg_lambda': 12.38954864437731}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:38:10,192] Trial 98 finished with value: 0.6683567566057435 and parameters: {'n_estimators': 1209, 'max_depth': 7, 'learning_rate': 0.09724051814547433, 'subsample': 0.5950334819393598, 'colsample_bytree': 0.5213440928310826, 'gamma': 6.537568680599801, 'min_child_weight': 13, 'reg_alpha': 5.305655781731314, 'reg_lambda': 3.905763775237785}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:38:14,398] Trial 99 finished with value: 0.6683955114333697 and parameters: {'n_estimators': 1440, 'max_depth': 9, 'learning_rate': 0.12158344328000605, 'subsample': 0.7655842755296594, 'colsample_bytree': 0.5853674628466555, 'gamma': 4.604399286135618, 'min_child_weight': 13, 'reg_alpha': 6.499657876899752, 'reg_lambda': 4.785573952760582}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:38:18,347] Trial 100 finished with value: 0.6703744863882929 and parameters: {'n_estimators': 1502, 'max_depth': 7, 'learning_rate': 0.11249201939745575, 'subsample': 0.5005175629623873, 'colsample_bytree': 0.5369918378223523, 'gamma': 5.016453254351267, 'min_child_weight': 2, 'reg_alpha': 9.68083739722293, 'reg_lambda': 3.227856564999416}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:38:22,902] Trial 101 finished with value: 0.6697509541666367 and parameters: {'n_estimators': 977, 'max_depth': 8, 'learning_rate': 0.1262018240952409, 'subsample': 0.5154688177911491, 'colsample_bytree': 0.557111022670697, 'gamma': 7.664210580189283, 'min_child_weight': 14, 'reg_alpha': 7.2840409842686205, 'reg_lambda': 13.015230164038316}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:38:26,635] Trial 102 finished with value: 0.6670235597966723 and parameters: {'n_estimators': 1386, 'max_depth': 8, 'learning_rate': 0.13259190027912884, 'subsample': 0.5082831230428857, 'colsample_bytree': 0.5755622481575782, 'gamma': 7.186508465718951, 'min_child_weight': 14, 'reg_alpha': 8.035109957704366, 'reg_lambda': 10.68158469403399}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:38:30,315] Trial 103 finished with value: 0.6698854488855593 and parameters: {'n_estimators': 1473, 'max_depth': 8, 'learning_rate': 0.11844029317356751, 'subsample': 0.5255314187395694, 'colsample_bytree': 0.5398483193161386, 'gamma': 8.20818734999813, 'min_child_weight': 15, 'reg_alpha': 6.8465281340361495, 'reg_lambda': 11.463380265049596}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:38:36,304] Trial 104 finished with value: 0.6692401076115375 and parameters: {'n_estimators': 1597, 'max_depth': 9, 'learning_rate': 0.1214395979159621, 'subsample': 0.5518708626996413, 'colsample_bytree': 0.612852026794874, 'gamma': 6.851946391131439, 'min_child_weight': 13, 'reg_alpha': 8.893020555969247, 'reg_lambda': 8.762869978272198}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:38:40,472] Trial 105 finished with value: 0.6701753135750868 and parameters: {'n_estimators': 1546, 'max_depth': 8, 'learning_rate': 0.13478038567110978, 'subsample': 0.5686667354760955, 'colsample_bytree': 0.5026879811064854, 'gamma': 6.245240965887528, 'min_child_weight': 14, 'reg_alpha': 7.6167967714528935, 'reg_lambda': 9.762439400974781}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:38:46,802] Trial 106 finished with value: 0.6707150453282936 and parameters: {'n_estimators': 1773, 'max_depth': 9, 'learning_rate': 0.14258027697593137, 'subsample': 0.5390007600311286, 'colsample_bytree': 0.6473557728967152, 'gamma': 5.301284286105152, 'min_child_weight': 15, 'reg_alpha': 8.156937353830763, 'reg_lambda': 11.314809306185506}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:38:51,474] Trial 107 finished with value: 0.6690432819875513 and parameters: {'n_estimators': 1685, 'max_depth': 9, 'learning_rate': 0.14092812579887132, 'subsample': 0.5380323946245568, 'colsample_bytree': 0.6487913816480755, 'gamma': 5.28957320196911, 'min_child_weight': 15, 'reg_alpha': 8.156896884020442, 'reg_lambda': 12.170715988453853}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:38:55,800] Trial 108 finished with value: 0.6613999430506803 and parameters: {'n_estimators': 1726, 'max_depth': 10, 'learning_rate': 0.14710418117107754, 'subsample': 0.9121454539027557, 'colsample_bytree': 0.6241524468946391, 'gamma': 5.540410973295846, 'min_child_weight': 15, 'reg_alpha': 8.608565476742925, 'reg_lambda': 3.5666953701883215}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:39:02,595] Trial 109 finished with value: 0.6689175344048008 and parameters: {'n_estimators': 1832, 'max_depth': 9, 'learning_rate': 0.1371158215270008, 'subsample': 0.6205782358393994, 'colsample_bytree': 0.6972971371215791, 'gamma': 5.983102351376399, 'min_child_weight': 15, 'reg_alpha': 12.033687989526316, 'reg_lambda': 2.5556812068182064}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:39:07,610] Trial 110 finished with value: 0.6677137946733515 and parameters: {'n_estimators': 1774, 'max_depth': 10, 'learning_rate': 0.14195538632964833, 'subsample': 0.56118446679303, 'colsample_bytree': 0.6014114736921633, 'gamma': 4.9270502916928915, 'min_child_weight': 14, 'reg_alpha': 9.220706226677377, 'reg_lambda': 1.3077938252447803}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:39:14,253] Trial 111 finished with value: 0.6700719872976743 and parameters: {'n_estimators': 1865, 'max_depth': 9, 'learning_rate': 0.1308416528671362, 'subsample': 0.5131049091659449, 'colsample_bytree': 0.5829167946507913, 'gamma': 7.584528474235612, 'min_child_weight': 14, 'reg_alpha': 6.964176448868082, 'reg_lambda': 11.627747230653203}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:39:18,676] Trial 112 finished with value: 0.6650298352678169 and parameters: {'n_estimators': 1788, 'max_depth': 8, 'learning_rate': 0.12418533894507655, 'subsample': 0.82566800801951, 'colsample_bytree': 0.566001191402997, 'gamma': 7.294500004473047, 'min_child_weight': 15, 'reg_alpha': 7.54116843884641, 'reg_lambda': 11.114667600383648}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:39:25,458] Trial 113 finished with value: 0.670298243029389 and parameters: {'n_estimators': 1891, 'max_depth': 9, 'learning_rate': 0.10378516635887806, 'subsample': 0.5284701643571121, 'colsample_bytree': 0.5560835514425794, 'gamma': 9.379790159413535, 'min_child_weight': 13, 'reg_alpha': 5.8244721538464646, 'reg_lambda': 11.269041009579414}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:39:30,674] Trial 114 finished with value: 0.6638368882254804 and parameters: {'n_estimators': 1910, 'max_depth': 8, 'learning_rate': 0.12749326112830284, 'subsample': 0.5463363526998066, 'colsample_bytree': 0.6431591093324381, 'gamma': 4.036679744877972, 'min_child_weight': 14, 'reg_alpha': 6.418820260316244, 'reg_lambda': 4.474668915188153}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:39:38,483] Trial 115 finished with value: 0.6708859205888537 and parameters: {'n_estimators': 2000, 'max_depth': 7, 'learning_rate': 0.0411385634633693, 'subsample': 0.5822133499500781, 'colsample_bytree': 0.6296747989174317, 'gamma': 3.502482716304709, 'min_child_weight': 15, 'reg_alpha': 11.085721535632505, 'reg_lambda': 13.649037606030396}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:39:44,166] Trial 116 finished with value: 0.6714069328159848 and parameters: {'n_estimators': 1971, 'max_depth': 7, 'learning_rate': 0.05069777363227476, 'subsample': 0.5990926197703016, 'colsample_bytree': 0.6353666164006435, 'gamma': 3.5547499587503637, 'min_child_weight': 15, 'reg_alpha': 11.213634481482902, 'reg_lambda': 13.731978168467608}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:39:51,797] Trial 117 finished with value: 0.6706657304269895 and parameters: {'n_estimators': 1973, 'max_depth': 7, 'learning_rate': 0.04377161275197288, 'subsample': 0.5843717623721485, 'colsample_bytree': 0.6323206634369783, 'gamma': 3.5774118888951882, 'min_child_weight': 15, 'reg_alpha': 11.334167318762583, 'reg_lambda': 13.764224574091026}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:39:58,563] Trial 118 finished with value: 0.6707530674473962 and parameters: {'n_estimators': 2000, 'max_depth': 7, 'learning_rate': 0.03602940042206181, 'subsample': 0.5835673016123314, 'colsample_bytree': 0.6644954474826306, 'gamma': 3.2237529272610725, 'min_child_weight': 15, 'reg_alpha': 11.07890756356089, 'reg_lambda': 13.980880904119823}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:40:06,381] Trial 119 finished with value: 0.6692221978429067 and parameters: {'n_estimators': 1991, 'max_depth': 7, 'learning_rate': 0.02978028226387421, 'subsample': 0.5907632593760379, 'colsample_bytree': 0.6682132065325995, 'gamma': 3.114545627156297, 'min_child_weight': 15, 'reg_alpha': 12.78304197019742, 'reg_lambda': 14.814893619957122}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:40:12,520] Trial 120 finished with value: 0.670453726021413 and parameters: {'n_estimators': 1967, 'max_depth': 6, 'learning_rate': 0.0348390426658165, 'subsample': 0.577613270670779, 'colsample_bytree': 0.6790247311156107, 'gamma': 2.812079413485765, 'min_child_weight': 14, 'reg_alpha': 13.380562344787473, 'reg_lambda': 14.056652592503326}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:40:19,904] Trial 121 finished with value: 0.6706284353159873 and parameters: {'n_estimators': 1991, 'max_depth': 7, 'learning_rate': 0.043456167956083445, 'subsample': 0.6008618865290561, 'colsample_bytree': 0.6327578875220762, 'gamma': 3.6685085871104257, 'min_child_weight': 15, 'reg_alpha': 11.191626891178801, 'reg_lambda': 13.681248707354499}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:40:25,071] Trial 122 finished with value: 0.6694975164058912 and parameters: {'n_estimators': 1959, 'max_depth': 7, 'learning_rate': 0.05154846887588778, 'subsample': 0.6259069769563179, 'colsample_bytree': 0.6484960228627672, 'gamma': 3.4033541260578533, 'min_child_weight': 15, 'reg_alpha': 12.46047697529928, 'reg_lambda': 15.71980505561762}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:40:32,446] Trial 123 finished with value: 0.6696485926888059 and parameters: {'n_estimators': 1936, 'max_depth': 7, 'learning_rate': 0.04272994655318313, 'subsample': 0.5819822783409524, 'colsample_bytree': 0.6233206703065584, 'gamma': 3.3521123857887667, 'min_child_weight': 15, 'reg_alpha': 10.858522953976294, 'reg_lambda': 14.318900878991744}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:40:38,807] Trial 124 finished with value: 0.6703220271029674 and parameters: {'n_estimators': 1993, 'max_depth': 6, 'learning_rate': 0.035596176631418536, 'subsample': 0.5652642392669658, 'colsample_bytree': 0.6579193823627223, 'gamma': 2.8729751908577703, 'min_child_weight': 14, 'reg_alpha': 11.619702695557631, 'reg_lambda': 13.381014828463059}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:40:46,090] Trial 125 finished with value: 0.6708800522599445 and parameters: {'n_estimators': 1971, 'max_depth': 7, 'learning_rate': 0.04895438977164103, 'subsample': 0.6120679782153647, 'colsample_bytree': 0.6371406498561424, 'gamma': 3.504384895091143, 'min_child_weight': 15, 'reg_alpha': 10.424144558287267, 'reg_lambda': 12.954695336289854}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:40:51,069] Trial 126 finished with value: 0.6688780025112295 and parameters: {'n_estimators': 1809, 'max_depth': 7, 'learning_rate': 0.053326344778516555, 'subsample': 0.6094134255581444, 'colsample_bytree': 0.6152787718928194, 'gamma': 4.324965251679541, 'min_child_weight': 14, 'reg_alpha': 10.327824457998428, 'reg_lambda': 11.886880757046198}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:40:58,338] Trial 127 finished with value: 0.6704614039742381 and parameters: {'n_estimators': 1944, 'max_depth': 6, 'learning_rate': 0.06281413718689599, 'subsample': 0.5960111748499792, 'colsample_bytree': 0.6526565918045161, 'gamma': 4.0142843865009725, 'min_child_weight': 13, 'reg_alpha': 9.864040546764606, 'reg_lambda': 12.57590788632449}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:41:03,756] Trial 128 finished with value: 0.6669887602054239 and parameters: {'n_estimators': 1704, 'max_depth': 7, 'learning_rate': 0.04755436240668056, 'subsample': 0.6311299471832831, 'colsample_bytree': 0.7313132490197096, 'gamma': 2.3859306337303243, 'min_child_weight': 6, 'reg_alpha': 10.422573251341403, 'reg_lambda': 12.793252694021183}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:41:10,518] Trial 129 finished with value: 0.6694497486298772 and parameters: {'n_estimators': 1841, 'max_depth': 7, 'learning_rate': 0.05130041591062342, 'subsample': 0.5717780763235184, 'colsample_bytree': 0.7115545657247754, 'gamma': 4.542387448338235, 'min_child_weight': 9, 'reg_alpha': 11.906001534991594, 'reg_lambda': 19.822554991476316}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:41:16,506] Trial 130 finished with value: 0.6697052800079241 and parameters: {'n_estimators': 1873, 'max_depth': 7, 'learning_rate': 0.018811618886576828, 'subsample': 0.5524270757006331, 'colsample_bytree': 0.6410125725720345, 'gamma': 2.6416355636619033, 'min_child_weight': 12, 'reg_alpha': 10.833696782677492, 'reg_lambda': 14.422597538050711}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:41:23,848] Trial 131 finished with value: 0.6698626209784931 and parameters: {'n_estimators': 1961, 'max_depth': 7, 'learning_rate': 0.041619342476907406, 'subsample': 0.6180830462804743, 'colsample_bytree': 0.6269280423437411, 'gamma': 3.082207935376192, 'min_child_weight': 15, 'reg_alpha': 11.378755929389508, 'reg_lambda': 15.251343461837777}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:41:29,448] Trial 132 finished with value: 0.6693527223711982 and parameters: {'n_estimators': 1975, 'max_depth': 7, 'learning_rate': 0.02865797148503816, 'subsample': 0.5824639323577699, 'colsample_bytree': 0.7657639422612843, 'gamma': 3.489082411846476, 'min_child_weight': 15, 'reg_alpha': 12.452539680543207, 'reg_lambda': 13.262687842152387}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:41:36,765] Trial 133 finished with value: 0.670249046161575 and parameters: {'n_estimators': 1999, 'max_depth': 7, 'learning_rate': 0.046046658842610604, 'subsample': 0.5895978017431804, 'colsample_bytree': 0.633498092096856, 'gamma': 3.59583373475606, 'min_child_weight': 15, 'reg_alpha': 11.077103709283366, 'reg_lambda': 13.443652388394943}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:41:42,089] Trial 134 finished with value: 0.6704528209001416 and parameters: {'n_estimators': 1924, 'max_depth': 7, 'learning_rate': 0.033281086387895106, 'subsample': 0.599755195150782, 'colsample_bytree': 0.6080482754825945, 'gamma': 3.9578421737169425, 'min_child_weight': 14, 'reg_alpha': 10.11611380257084, 'reg_lambda': 12.891736395625689}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:41:49,400] Trial 135 finished with value: 0.670312735313655 and parameters: {'n_estimators': 1973, 'max_depth': 6, 'learning_rate': 0.05423103547503501, 'subsample': 0.5602248918523014, 'colsample_bytree': 0.6632308681229848, 'gamma': 3.6767245407286206, 'min_child_weight': 15, 'reg_alpha': 11.402258051383729, 'reg_lambda': 12.17212831339192}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:41:54,527] Trial 136 finished with value: 0.6684659097820033 and parameters: {'n_estimators': 1753, 'max_depth': 8, 'learning_rate': 0.039503156411941194, 'subsample': 0.6561478715552251, 'colsample_bytree': 0.6838672239473541, 'gamma': 2.9994331147006683, 'min_child_weight': 15, 'reg_alpha': 9.48666313111688, 'reg_lambda': 13.844560415627619}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:42:01,866] Trial 137 finished with value: 0.6697533518970118 and parameters: {'n_estimators': 1999, 'max_depth': 7, 'learning_rate': 0.04936984367661567, 'subsample': 0.6132159103942815, 'colsample_bytree': 0.6379655859851391, 'gamma': 3.310725682355329, 'min_child_weight': 14, 'reg_alpha': 13.409012220807854, 'reg_lambda': 15.677336743710313}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:42:07,066] Trial 138 finished with value: 0.6708605001909391 and parameters: {'n_estimators': 1948, 'max_depth': 8, 'learning_rate': 0.03786204845525004, 'subsample': 0.6377224251636587, 'colsample_bytree': 0.6736728167634677, 'gamma': 4.2293338692662825, 'min_child_weight': 13, 'reg_alpha': 10.476668108766866, 'reg_lambda': 14.485491467831455}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:42:13,485] Trial 139 finished with value: 0.6693636357713039 and parameters: {'n_estimators': 1501, 'max_depth': 8, 'learning_rate': 0.031067707398641477, 'subsample': 0.5405413015643129, 'colsample_bytree': 0.65598715264712, 'gamma': 4.273983042286741, 'min_child_weight': 13, 'reg_alpha': 9.048404970183686, 'reg_lambda': 0.6770050816127}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:42:17,759] Trial 140 finished with value: 0.6678480795271067 and parameters: {'n_estimators': 1437, 'max_depth': 8, 'learning_rate': 0.022401426340354177, 'subsample': 0.6805392785185013, 'colsample_bytree': 0.6706548979656909, 'gamma': 4.76040115083019, 'min_child_weight': 12, 'reg_alpha': 10.534692981244905, 'reg_lambda': 14.58325574922201}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:42:24,827] Trial 141 finished with value: 0.6695545385196958 and parameters: {'n_estimators': 1946, 'max_depth': 8, 'learning_rate': 0.037784665779132545, 'subsample': 0.6401220756533135, 'colsample_bytree': 0.6887488072560772, 'gamma': 3.88362262838892, 'min_child_weight': 13, 'reg_alpha': 11.810164919867155, 'reg_lambda': 16.132491698596343}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:42:29,867] Trial 142 finished with value: 0.6691270775541718 and parameters: {'n_estimators': 1922, 'max_depth': 7, 'learning_rate': 0.057785176605369984, 'subsample': 0.5746082094864541, 'colsample_bytree': 0.6128308004581926, 'gamma': 4.160821830091674, 'min_child_weight': 14, 'reg_alpha': 10.779730772472863, 'reg_lambda': 13.98033273791367}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:42:36,948] Trial 143 finished with value: 0.6691495407335275 and parameters: {'n_estimators': 1961, 'max_depth': 8, 'learning_rate': 0.04567619750465666, 'subsample': 0.6033230676088707, 'colsample_bytree': 0.6305233186617556, 'gamma': 3.51919224988111, 'min_child_weight': 13, 'reg_alpha': 12.15071611757508, 'reg_lambda': 12.492188466714088}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:42:41,290] Trial 144 finished with value: 0.6696521114219042 and parameters: {'n_estimators': 1583, 'max_depth': 8, 'learning_rate': 0.039064761065212054, 'subsample': 0.5868759130170224, 'colsample_bytree': 0.595525989135031, 'gamma': 3.811123020044909, 'min_child_weight': 15, 'reg_alpha': 9.871282589929198, 'reg_lambda': 13.606495384042617}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:42:46,704] Trial 145 finished with value: 0.6687193455614483 and parameters: {'n_estimators': 1887, 'max_depth': 8, 'learning_rate': 0.02529687147266288, 'subsample': 0.6220713375787544, 'colsample_bytree': 0.6473804890648418, 'gamma': 3.2890093676907752, 'min_child_weight': 14, 'reg_alpha': 11.221294577681833, 'reg_lambda': 15.2570748813543}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:42:52,731] Trial 146 finished with value: 0.6646966925209893 and parameters: {'n_estimators': 1636, 'max_depth': 5, 'learning_rate': 0.0711177086595674, 'subsample': 0.6101441570242091, 'colsample_bytree': 0.6193059173111858, 'gamma': 4.463796136889326, 'min_child_weight': 15, 'reg_alpha': 18.68941510786263, 'reg_lambda': 14.25468982323282}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:42:56,739] Trial 147 finished with value: 0.6690756361079773 and parameters: {'n_estimators': 1360, 'max_depth': 7, 'learning_rate': 0.04105578726327859, 'subsample': 0.5657876261603211, 'colsample_bytree': 0.6039842210629225, 'gamma': 4.629895235209841, 'min_child_weight': 14, 'reg_alpha': 10.257885692185495, 'reg_lambda': 13.058155633612985}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:43:02,620] Trial 148 finished with value: 0.6681045678842988 and parameters: {'n_estimators': 1524, 'max_depth': 7, 'learning_rate': 0.04403070659632144, 'subsample': 0.7160314050058806, 'colsample_bytree': 0.6751974676131864, 'gamma': 5.167348894216312, 'min_child_weight': 13, 'reg_alpha': 8.734660416581214, 'reg_lambda': 5.062230897720156}. Best is trial 24 with value: 0.6721380395681495.
# [I 2026-02-11 18:43:08,534] Trial 149 finished with value: 0.6686853396990051 and parameters: {'n_estimators': 1903, 'max_depth': 8, 'learning_rate': 0.032093001503239384, 'subsample': 0.5325529983684346, 'colsample_bytree': 0.6391250830983582, 'gamma': 2.6110663907758793, 'min_child_weight': 15, 'reg_alpha': 9.362138856602048, 'reg_lambda': 13.778899903949476}. Best is trial 24 with value: 0.6721380395681495.
# Best Params Found:
# {'n_estimators': 1788, 'max_depth': 9, 'learning_rate': 0.12413495586925252, 'subsample': 0.5965306041991241, 'colsample_bytree': 0.6300681036179655, 'gamma': 3.7805016511251135, 'min_child_weight': 14, 'reg_alpha': 10.869924819619547, 'reg_lambda': 4.7449117733302595, 'scale_pos_weight': np.float64(2.768561872909699), 'tree_method': 'hist', 'predictor': 'gpu_predictor', 'eval_metric': 'aucpr', 'random_state': 42, 'n_jobs': -1}
#
# 🔥 FINAL XGBOOST AUC: 0.8491565269058876
# 🔥 FINAL AUC-PR: 0.663707286066256
# Features kept: 31
#
# 🔥 PRUNED MODEL AUC: 0.8500542509493916
# Best Threshold: 0.5300000000000002
#
# ===== FINAL CLASSIFICATION REPORT =====
#               precision    recall  f1-score   support
#
#            0       0.91      0.76      0.83      1035
#            1       0.54      0.79      0.64       374
#
#     accuracy                           0.77      1409
#    macro avg       0.72      0.77      0.73      1409
# weighted avg       0.81      0.77      0.78      1409
#
# FINAL AUC: 0.8500542509493916
